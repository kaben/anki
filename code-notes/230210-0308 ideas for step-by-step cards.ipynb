# %%
import sympy as sy

# %%
a,b,c,r,s,t,u,v,w,x,y,z,theta = sy.symbols('a,b,c,r,s,t,u,v,w,x,y,z,theta')

# %%
ex = (x + sy.ln(4*x**2 - 4*x + 3)/8 - sy.atan((2*x - 1)/sy.sqrt(2))/(4*sy.sqrt(2))) - (x + sy.ln(4*x**2 - 4*x + 3)/8 - sy.atan((2*x - 1)/sy.sqrt(2))/(2*sy.sqrt(2)))
ex
# Out:
# sqrt(2)*atan(sqrt(2)*(2*x - 1)/2)/8

# %%
ex.simplify()
# Out:
# sqrt(2)*atan(sqrt(2)*(2*x - 1)/2)/8

# %%
for i in range(1,21):
    print(f'''
  {{{{#Step{i}Name}}}}
    document.getElementById('step{i}_name').innerHTML = String.raw`{{{{Step{i}Name}}}}`;
  {{{{/Step{i}Name}}}}
  {{{{#Step{i}}}}}
    document.getElementById('step{i}').innerHTML = String.raw`{{{{Step{i}}}}}`;
  {{{{/Step{i}}}}}''')
# Out:
#   {{#Step1Name}}
#     document.getElementById('step1_name').innerHTML = String.raw`{{Step1Name}}`;
#   {{/Step1Name}}
#   {{#Step1}}
#     document.getElementById('step1').innerHTML = String.raw`{{Step1}}`;
#   {{/Step1}}
#
#   {{#Step2Name}}
#     document.getElementById('step2_name').innerHTML = String.raw`{{Step2Name}}`;
#   {{/Step2Name}}
#   {{#Step2}}
#     document.getElementById('step2').innerHTML = String.raw`{{Step2}}`;
#   {{/Step2}}
#
#   {{#Step3Name}}
#     document.getElementById('step3_name').innerHTML = String.raw`{{Step3Name}}`;
#   {{/Step3Name}}
#   {{#Step3}}
#     document.getElementById('step3').innerHTML = String.raw`{{Step3}}`;
#   {{/Step3}}
#
#   {{#Step4Name}}
#     document.getElementById('step4_name').innerHTML = String.raw`{{Step4Name}}`;
#   {{/Step4Name}}
#   {{#Step4}}
#     document.getElementById('step4').innerHTML = String.raw`{{Step4}}`;
#   {{/Step4}}
#
#   {{#Step5Name}}
# ...

# %%
for i in range(1,21):
    print(f'''
{{{{#Step{i}Name}}}}
  <div id='step{i}_name' class='step_name'>{{{{Step{i}Name}}}}</div>
{{{{/Step{i}Name}}}}
{{{{#Step{i}}}}}
  <div id='step{i}' class='blank'>{{{{Step{i}}}}}</div>
{{{{/Step{i}}}}}''')
# Out:
# {{#Step1Name}}
#   <div id='step1_name' class='step_name'>{{Step1Name}}</div>
# {{/Step1Name}}
# {{#Step1}}
#   <div id='step1' class='blank'>{{Step1}}</div>
# {{/Step1}}
#
# {{#Step2Name}}
#   <div id='step2_name' class='step_name'>{{Step2Name}}</div>
# {{/Step2Name}}
# {{#Step2}}
#   <div id='step2' class='blank'>{{Step2}}</div>
# {{/Step2}}
#
# {{#Step3Name}}
#   <div id='step3_name' class='step_name'>{{Step3Name}}</div>
# {{/Step3Name}}
# {{#Step3}}
#   <div id='step3' class='blank'>{{Step3}}</div>
# {{/Step3}}
#
# {{#Step4Name}}
#   <div id='step4_name' class='step_name'>{{Step4Name}}</div>
# {{/Step4Name}}
# {{#Step4}}
#   <div id='step4' class='blank'>{{Step4}}</div>
# {{/Step4}}
#
# {{#Step5Name}}
#   <div id='step5_name' class='step_name'>{{Step5Name}}</div>
# {{/Step5Name}}
# {{#Step5}}
#   <div id='step5' class='blank'>{{Step5}}</div>
# {{/Step5}}
#
# {{#Step6Name}}
#   <div id='step6_name' class='step_name'>{{Step6Name}}</div>
# {{/Step6Name}}
# {{#Step6}}
# ...

# %%
for i in range(1,21):
    print(f'''
{{{{#Step{i}Name}}}}
  <div id='step{i}_name' class='step_name'>{{{{Step{i}Name}}}}</div>
{{{{/Step{i}Name}}}}
{{{{#Step{i}}}}}
  <div id='step{i}' class='step'>{{{{Step{i}}}}}</div>
{{{{/Step{i}}}}}''')
# Out:
# {{#Step1Name}}
#   <div id='step1_name' class='step_name'>{{Step1Name}}</div>
# {{/Step1Name}}
# {{#Step1}}
#   <div id='step1' class='step'>{{Step1}}</div>
# {{/Step1}}
#
# {{#Step2Name}}
#   <div id='step2_name' class='step_name'>{{Step2Name}}</div>
# {{/Step2Name}}
# {{#Step2}}
#   <div id='step2' class='step'>{{Step2}}</div>
# {{/Step2}}
#
# {{#Step3Name}}
#   <div id='step3_name' class='step_name'>{{Step3Name}}</div>
# {{/Step3Name}}
# {{#Step3}}
#   <div id='step3' class='step'>{{Step3}}</div>
# {{/Step3}}
#
# {{#Step4Name}}
#   <div id='step4_name' class='step_name'>{{Step4Name}}</div>
# {{/Step4Name}}
# {{#Step4}}
#   <div id='step4' class='step'>{{Step4}}</div>
# {{/Step4}}
#
# {{#Step5Name}}
#   <div id='step5_name' class='step_name'>{{Step5Name}}</div>
# {{/Step5Name}}
# {{#Step5}}
#   <div id='step5' class='step'>{{Step5}}</div>
# {{/Step5}}
#
# {{#Step6Name}}
#   <div id='step6_name' class='step_name'>{{Step6Name}}</div>
# {{/Step6Name}}
# {{#Step6}}
# ...
