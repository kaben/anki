# %%
# %run code-notes/library/_230210-0303_math-problem-randomization-library.ipynb

# %% [markdown]
# ### CET-09.03-01 Exercise:
#
# ```
# CET-09.03-01 Exercise:
# <br>
# Solve the differential equation.
# \[
# \frac{d y}{d x}=3 x^2 y^2
# \]
# ```
#
#
# ```
# CET-09.03-01 Exercise:
# <br>
# Solve the differential equation.
# \[
# \frac{d y}{d x}=${a} x^2 ${b} y^2
# \]
# ```

# %%
f = sy.Function('y')
ex = sy.Eq(sy.Derivative(f(x)), a*x**2 * f(x)**2)
display.display_latex(ex)
sy.dsolve(ex, f(x))
# Out:
# $\displaystyle \frac{d}{d x} y{\left(x \right)} = a x^{2} y^{2}{\left(x \right)}$
# Eq(y(x), -3/(C1 + a*x**3))

# %%
params = {
    a: range(1,10),
}

# %%
def get_probsol(ex, args_list):
    prob = subs_items(ex, args_list)
    sol = sy.dsolve(prob, f(x))
    return True,prob,sol

# %%
param_script = get_params_script(
    ex,
    params,
    show_vars = False,
    show_prob = True,
    show_sol = True,
    probsol_func = get_probsol
)

# %%
print(param_script)
# Out:
# if (typeof params === 'undefined') { let params,prob,sol; }
# params = [
#   [String.raw`\frac{d}{d x} y{\left(x \right)} = x^{2} y^{2}{\left(x \right)}`,String.raw`y{\left(x \right)} = - \frac{3}{C_{1} + x^{3}}`,],
#   [String.raw`\frac{d}{d x} y{\left(x \right)} = 2 x^{2} y^{2}{\left(x \right)}`,String.raw`y{\left(x \right)} = - \frac{3}{C_{1} + 2 x^{3}}`,],
#   [String.raw`\frac{d}{d x} y{\left(x \right)} = 3 x^{2} y^{2}{\left(x \right)}`,String.raw`y{\left(x \right)} = - \frac{1}{C_{1} + x^{3}}`,],
#   [String.raw`\frac{d}{d x} y{\left(x \right)} = 4 x^{2} y^{2}{\left(x \right)}`,String.raw`y{\left(x \right)} = - \frac{3}{C_{1} + 4 x^{3}}`,],
#   [String.raw`\frac{d}{d x} y{\left(x \right)} = 5 x^{2} y^{2}{\left(x \right)}`,String.raw`y{\left(x \right)} = - \frac{3}{C_{1} + 5 x^{3}}`,],
#   [String.raw`\frac{d}{d x} y{\left(x \right)} = 6 x^{2} y^{2}{\left(x \right)}`,String.raw`y{\left(x \right)} = - \frac{1}{C_{1} + 2 x^{3}}`,],
# ...

# %%
11.5**2
# Out:
# 132.25

# %%
sy.plot(x, sy.sin(x), (x, 0, sy.pi))

# %%
1000 * 9.8 * 0.2**2 * (1 - 0.2)
# Out:
# 313.6000000000001

# %%
0.20 * 1e3 * 9.8 * ((.02 + 0.16))
# Out:
# 352.8

# %%
1200/(1 + 19*sy.exp(-0.4))
# Out:
# 87.3611629800632

# %%
500/(1 + 23/2 * sy.exp(-0.2))
# Out:
# 48.0058206386359

# %%
T = 2**(-0.01)/(2**(-0.01) - 16**(-0.01))*3
T
# Out:
# 145.77470265528558

# %%
T//12
# Out:
# 12.0

# %%
T%12
# Out:
# 1.77470265528558

# %%
(1200)/(1 + 19*sy.exp(-0.04*10))
# Out:
# 87.3611629800632

# %%
(500)/(1 + 11.5*sy.exp(-0.02*10))
# Out:
# 48.0058206386359

# %%
(10000)/(1 + 9*sy.exp(-sy.ln(3)*4))
# Out:
# 9000

# %%
(10000)/(1 + 9*3**(-4))
# Out:
# 9000.0

# %% [markdown]
# This is a math expression: $$\int_a^b \sin(x) \, dx$$

# %%
import matplotlib.pyplot as plt
import math

# %%
xs = list(range(10))
ys = [math.cos(x) for x in xs]
ss = [sum(math.cos(n) for n in range(x+1)) for x in xs] 
plt.plot(xs, ss)

# %%
ss
# Out:
# [1.0,
#  1.5403023058681398,
#  1.1241554693209974,
#  0.134162972720552,
#  -0.5194806481430599,
#  -0.2358184626798337,
#  0.7243518239705322,
#  1.478254078313837,
#  1.3327540445052235,
#  0.42162378262054656]
# 1678576646.153 GET /_anki/css/toolbar.css
# 1678944446.986 GET /_anki/js/deckbrowser.js

# %%
sy.plot((2*x)/(x**2 + 4), (x, 0, 2))

# %%
sy.plot(x**3 - 3*x + 4, (x, 1, 3))

# %%
xr = (x, 1.97, 2.03)
yr = (y, 5.79, 6.21)
p1 = sy.plot_implicit(sy.Eq(x**3 - 3*x + 4, y), xr, yr, show=False)
p1.append(sy.plot_implicit(sy.Eq(y, 5.8), xr, yr, show=False)[0])
p1.append(sy.plot_implicit(sy.Eq(y, 6.2), xr, yr, show=False)[0])
p1.append(sy.plot_implicit(sy.Eq(x, 1.979), xr, yr, show=False)[0])
p1.append(sy.plot_implicit(sy.Eq(x, 2.021), xr, yr, show=False)[0])
p1.show()

# %%
xr = (x, 1.97, 2.03)
yr = (y, 5.89, 6.11)
p1 = sy.plot_implicit(sy.Eq(x**3 - 3*x + 4, y), xr, yr, show=False)
p1.append(sy.plot_implicit(sy.Eq(y, 5.9), xr, yr, show=False)[0])
p1.append(sy.plot_implicit(sy.Eq(y, 6.1), xr, yr, show=False)[0])
p1.append(sy.plot_implicit(sy.Eq(x, 1.990), xr, yr, show=False)[0])
p1.append(sy.plot_implicit(sy.Eq(x, 2.010), xr, yr, show=False)[0])
p1.show()

# %%
xr = (x, -0.25, 0.25)
yr = (y, 1.49, 2.51)
p1 = sy.plot_implicit(sy.Eq((sy.exp(2*x) - 1)/x, y), xr, yr, show=False)
p1.append(sy.plot_implicit(sy.Eq(y, 1.5), xr, yr, show=False)[0])
p1.append(sy.plot_implicit(sy.Eq(y, 2.5), xr, yr, show=False)[0])
p1.append(sy.plot_implicit(sy.Eq(x, -0.2), xr, yr, show=False)[0])
p1.append(sy.plot_implicit(sy.Eq(x, 0.2), xr, yr, show=False)[0])
p1.show()

# %%
xr = (x, -0.05, 0.05)
yr = (y, 1.89, 2.11)
p1 = sy.plot_implicit(sy.Eq((sy.exp(2*x) - 1)/x, y), xr, yr, show=False)
p1.append(sy.plot_implicit(sy.Eq(y, 1.9), xr, yr, show=False)[0])
p1.append(sy.plot_implicit(sy.Eq(y, 2.1), xr, yr, show=False)[0])
p1.append(sy.plot_implicit(sy.Eq(x, -0.04), xr, yr, show=False)[0])
p1.append(sy.plot_implicit(sy.Eq(x, 0.04), xr, yr, show=False)[0])
p1.show()

# %%
math.exp(0.01) + 1
# Out:
# 2.010050167084168

# %%
math.log(1.01)
# Out:
# 0.009950330853168092

# %%
1/math.log(1.01)
# Out:
# 100.49917080713044

# %%
xr = (x, 2, 2.02)
yr = (y, 90, 110)
p1 = sy.plot_implicit(sy.Eq(1/sy.log(x-1), y), xr, yr, show=False)
p1.append(sy.plot_implicit(sy.Eq(y, 100), xr, yr, show=False)[0])
p1.append(sy.plot_implicit(sy.Eq(y, 100.5), xr, yr, show=False)[0])
p1.append(sy.plot_implicit(sy.Eq(x, 2), xr, yr, show=False)[0])
p1.append(sy.plot_implicit(sy.Eq(x, 2.01), xr, yr, show=False)[0])
p1.show()

# %%
r = (1000/math.pi)**0.5
r
# Out:
# 17.841241161527712

# %%
r-((1000-5)/math.pi)**0.5
# Out:
# 0.04465899660425521

# %%
r-((1000+5)/math.pi)**0.5
# Out:
# -0.04454748797582653
# 1683766876.376 GET /_anki/js/deckbrowser.js

# %%
import aqt
browser = aqt.dialogs._dialogs['Browser'][1]
table = browser.table
model = table._model
reviews = [model._state.get_review(item) for item in model._items]
cards = [model._state.get_card(item) for item in model._items]
notes = [model._state.get_note(item) for item in model._items]
#nt = cards[0].note().note_type()

# %%
notes[0].__dict__
# Out:
# {'col': <anki.collection.Collection at 0x7f272027f040>,
#  'id': 1677546031351,
#  'guid': 'xf,C%].#ip',
#  'mid': 1539794822805,
#  'mod': 1677546031,
#  'usn': 2447,
#  'tags': ['.Texts',
#   '.Texts::CET',
#   '.Texts::CET::C02-LimitsAndDerivatives',
#   '.Texts::CET::C02-LimitsAndDerivatives::CET-02.04-ThePreciseDefinitionOfALimit',
#   'Calculus',
#   'Exercises',
#   'Math'],
#  'fields': ['CET-02.04-17 Exercise:', '', '', ''],
#  '_fmap': {'Front': (0,
#    {'name': 'Front',
#     'ord': 0,
#     'sticky': False,
#     'rtl': False,
#     'font': 'Arial',
#     'size': 24,
#     'description': '',
#     'plainText': False,
#     'collapsed': False,
#     'media': []}),
#   'Back': (1,
#    {'name': 'Back',
#     'ord': 1,
#     'sticky': False,
#     'rtl': False,
#     'font': 'Liberation Serif',
#     'size': 24,
#     'description': '',
#     'plainText': False,
#     'collapsed': False,
#     'media': []}),
#   'Annotations': (2,
#    {'name': 'Annotations',
# ...

# %%
cards[0].__dict__
# Out:
# {'col': <anki.collection.Collection at 0x7f272027f040>,
#  'timer_started': None,
#  '_render_output': None,
#  'id': 1677546031352,
#  '_note': None,
#  'nid': 1677546031351,
#  'did': 1678142432973,
#  'ord': 0,
#  'mod': 1683828524,
#  'usn': -1,
#  'type': 1,
#  'queue': 1,
#  'due': 1683828589,
#  'ivl': 0,
#  'factor': 0,
#  'reps': 1,
#  'lapses': 0,
#  'left': 12,
#  'odue': 0,
#  'odid': 1677214914028,
#  'flags': 0,
#  'original_position': 16,
#  'custom_data': '{"v":"3.13.4","seed":4464,"d":6,"s":1}'}

# %%
reviews[0]
# Out:
# id: 1683828524041
# cid: 1677546031352
# usn: -1
# button_chosen: 1
# interval: -60
# taken_millis: 651306

# %%
divmod(651306/1000, 60)
# Out:
# (10.0, 51.30600000000004)

# %%
type(reviews[0])
# Out:
# anki.revlog_pb2.RevlogEntry

# %%
reviews[0].taken_millis
# Out:
# 651306

# %%
reviews[0].taken_millis = (1000)*(7*60 + 30)

# %%
reviews[0].taken_millis
# Out:
# 450000

# %%
mw.col.update_revlog_entry(reviews[0])
# Out:
# mtime: true
# revlog_entry: true
# browser_table: true
# 1683921075.895 GET /_anki/js/vendor/jquery-ui.min.js
# 1683921075.896 GET /_anki/css/deckbrowser.css
# 1684057875.892 GET /_anki/css/toolbar-bottom.css
# 1684126876.368 GET /_anki/legacyPageData
# 1684196475.927 GET /_anki/js/vendor/jquery-ui.min.js1684196475.928 GET /_anki/js/vendor/jquery.min.js
