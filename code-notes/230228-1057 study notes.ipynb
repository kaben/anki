# %% [markdown]
# 230228-1057 study notes

# %%
from IPython.display import Markdown

# %%
import sympy as sy

# %%
a,b,c,d,e,i,j,k,l,m,n,p,q,r,s,t,u,v,w,x,y,z,theta = sy.symbols('a,b,c,d,e,i,j,k,l,m,n,p,q,r,s,t,u,v,w,x,y,z,theta')

# %% [markdown]
# - [x] `02 Limits and derivatives::02.02 The limit of a function`
# - [x] `02 Limits and derivatives::02.03 Calculating limits using the limit laws`
# - [x] `02 Limits and derivatives::02.04 The precise definition of a limit`
# - [x] `02 Limits and derivatives::02.05 Continuity`
# - [x] `02 Limits and derivatives::02.06 Limits at infinity; horizontal asymptotes`
# - [x] `03 Differentiation rules::03.01 Derivatives of polynomials and exponential functions`
# - [x] `03 Differentiation rules::03.02 The product and quotient rules`
# - [x] `03 Differentiation rules::03.03 Derivatives of trigonometric functions`
# - [x] `03 Differentiation rules::03.04 The Chain Rule`
# - [x] `03 Differentiation rules::03.05 Implicit differentiation`
# - [x] `03 Differentiation rules::03.06 Derivatives of logarithmic functions`
# - [x] `03 Differentiation rules::03.07 Rates of change in the natural and social sciences`
# - [x] `03 Differentiation rules::03.08 Exponential growth and decay`
# - [x] `03 Differentiation rules::03.09 Related rates`
# - [x] `03 Differentiation rules::03.10 Linear approximations and differentials`
# - [x] `03 Differentiation rules::03.11 Hyperbolic functions`
# - [x] `04 Applications of differentiation::04.01 Maximum and minimum values`
# - [x] `04 Applications of differentiation::04.02 The Mean Value Theorem`
# - [x] `04 Applications of differentiation::04.04 Indeterminate forms and L'Hospital's Rule`
# - [x] `04 Applications of differentiation::04.07 Optimization problems`
# - [x] `04 Applications of differentiation::04.08 Newton's Method`
# - [x] `05 Integrals::05.03 The Fundamental Theorem of Calculus`
# - [x] `05 Integrals::05.05 The Substitution Rule`
# - [x] `06 Applications of integration::06.01 Areas between curves`
# - [x] `06 Applications of integration::06.02 Volumes`
# - [x] `06 Applications of integration::06.03 Volumes by cylindrical shells`
# - [x] `06 Applications of integration::06.04 Work`
# - [x] `06 Applications of integration::06.05 Average value of a function`
# - [x] `07 Techniques of integration::07.01 Integration by parts`
# - [x] `07 Techniques of integration::07.02 Trigonometric integrals`
# - [x] `07 Techniques of integration::07.03 Trigonometric substitution`
# - [x] `07 Techniques of integration::07.04 Integration of rational functions by partial fractions`
# - [x] `07 Techniques of integration::07.05 Strategy for integration`
# - [x] `07 Techniques of integration::07.07 Approximate integration`
# - [x] `07 Techniques of integration::07.08 Improper integrals`
# - [x] `08 Further applications of integration::08.01 Arc length`
# - [x] `08 Further applications of integration::08.02 Area of a surface of revolution`
# - [x] `08 Further applications of integration::08.03 Applications to physics and engineering`
# - [x] `09 Differential equations::09.01 Modeling with differential equations`
# - [ ] `09 Differential equations::09.02 Direction fields and Euler's Method`
# - [ ] `09 Differential equations::09.03 Separable equations`
# - [ ] `09 Differential equations::09.04 Models for population growth`
# - [ ] `09 Differential equations::09.05 Linear equations`
# - [ ] `09 Differential equations::09.06 Predator-prey systems`
# - [ ] `11 Infinite sequences and series::11.01 Sequences`
# - [ ] `11 Infinite sequences and series::11.02 Series`
# - [ ] `11 Infinite sequences and series::11.03 The integral test and estimates of sums`
# - [ ] `11 Infinite sequences and series::11.04 The comparison tests`
# - [ ] `11 Infinite sequences and series::11.05 Alternating series`
# - [ ] `11 Infinite sequences and series::11.06 Absolute convergence and the Ratio and Root Tests`
# - [ ] `11 Infinite sequences and series::11.07 Strategy for testing series`
# - [ ] `11 Infinite sequences and series::11.08 Power series`
# - [ ] `11 Infinite sequences and series::11.09 Representations of functions as power series`
# - [ ] `11 Infinite sequences and series::11.10 Taylor and Maclaurin series`
# - [ ] `11 Infinite sequences and series::11.11 Applications of Taylor polynomials`
# - [ ] `10 Parametric equations and polar coordinates::10.01 Curves defined by parametric equations`
# - [ ] `10 Parametric equations and polar coordinates::10.02 Calculus with parametric curves`
# - [ ] `10 Parametric equations and polar coordinates::10.03 Polar coordinates`
# - [ ] `10 Parametric equations and polar coordinates::10.04 Areas and lengths in polar coordinates`
# - [ ] `10 Parametric equations and polar coordinates::10.05 Conic sections`
# - [ ] `10 Parametric equations and polar coordinates::10.06 Conic sections in polar coordinates`

# %% [markdown]
# - [ ] `02 Limits and derivatives::02.02 The limit of a function`
# - [ ] `02 Limits and derivatives::02.03 Calculating limits using the limit laws`
# - [ ] `02 Limits and derivatives::02.04 The precise definition of a limit`
# - [ ] `02 Limits and derivatives::02.05 Continuity`
# - [ ] `02 Limits and derivatives::02.06 Limits at infinity; horizontal asymptotes`
# - [ ] `03 Differentiation rules::03.01 Derivatives of polynomials and exponential functions`
# - [ ] `03 Differentiation rules::03.02 The product and quotient rules`
# - [ ] `03 Differentiation rules::03.03 Derivatives of trigonometric functions`
# - [ ] `03 Differentiation rules::03.04 The Chain Rule`
# - [ ] `03 Differentiation rules::03.05 Implicit differentiation`
# - [ ] `03 Differentiation rules::03.06 Derivatives of logarithmic functions`
# - [ ] `03 Differentiation rules::03.07 Rates of change in the natural and social sciences`
# - [ ] `03 Differentiation rules::03.08 Exponential growth and decay`
# - [ ] `03 Differentiation rules::03.09 Related rates`
# - [ ] `03 Differentiation rules::03.10 Linear approximations and differentials`
# - [ ] `03 Differentiation rules::03.11 Hyperbolic functions`
# - [ ] `04 Applications of differentiation::04.01 Maximum and minimum values`
# - [ ] `04 Applications of differentiation::04.02 The Mean Value Theorem`
# - [ ] `04 Applications of differentiation::04.04 Indeterminate forms and L'Hospital's Rule`
# - [ ] `04 Applications of differentiation::04.07 Optimization problems`
# - [ ] `04 Applications of differentiation::04.08 Newton's Method`
# - [ ] `05 Integrals::05.03 The Fundamental Theorem of Calculus`
# - [ ] `05 Integrals::05.05 The Substitution Rule`
# - [ ] `06 Applications of integration::06.01 Areas between curves`
# - [ ] `06 Applications of integration::06.02 Volumes`
# - [ ] `06 Applications of integration::06.03 Volumes by cylindrical shells`
# - [ ] `06 Applications of integration::06.04 Work`
# - [ ] `06 Applications of integration::06.05 Average value of a function`
# - [ ] `07 Techniques of integration::07.01 Integration by parts`
# - [ ] `07 Techniques of integration::07.02 Trigonometric integrals`
# - [ ] `07 Techniques of integration::07.03 Trigonometric substitution`
# - [ ] `07 Techniques of integration::07.04 Integration of rational functions by partial fractions`
# - [ ] `07 Techniques of integration::07.05 Strategy for integration`
# - [ ] `07 Techniques of integration::07.07 Approximate integration`
# - [ ] `07 Techniques of integration::07.08 Improper integrals`
# - [ ] `08 Further applications of integration::08.01 Arc length`
# - [ ] `08 Further applications of integration::08.02 Area of a surface of revolution`
# - [ ] `08 Further applications of integration::08.03 Applications to physics and engineering`
# - [ ] `09 Differential equations::09.01 Modeling with differential equations`
# - [ ] `09 Differential equations::09.02 Direction fields and Euler's Method`
# - [ ] `09 Differential equations::09.03 Separable equations`
# - [ ] `09 Differential equations::09.04 Models for population growth`
# - [ ] `09 Differential equations::09.05 Linear equations`
# - [ ] `09 Differential equations::09.06 Predator-prey systems`
# - [ ] `11 Infinite sequences and series::11.01 Sequences`
# - [ ] `11 Infinite sequences and series::11.02 Series`
# - [ ] `11 Infinite sequences and series::11.03 The integral test and estimates of sums`
# - [ ] `11 Infinite sequences and series::11.04 The comparison tests`
# - [ ] `11 Infinite sequences and series::11.05 Alternating series`
# - [ ] `11 Infinite sequences and series::11.06 Absolute convergence and the Ratio and Root Tests`
# - [ ] `11 Infinite sequences and series::11.07 Strategy for testing series`
# - [ ] `11 Infinite sequences and series::11.08 Power series`
# - [ ] `11 Infinite sequences and series::11.09 Representations of functions as power series`
# - [ ] `11 Infinite sequences and series::11.10 Taylor and Maclaurin series`
# - [ ] `11 Infinite sequences and series::11.11 Applications of Taylor polynomials`
# - [ ] `10 Parametric equations and polar coordinates::10.01 Curves defined by parametric equations`
# - [ ] `10 Parametric equations and polar coordinates::10.02 Calculus with parametric curves`
# - [ ] `10 Parametric equations and polar coordinates::10.03 Polar coordinates`
# - [ ] `10 Parametric equations and polar coordinates::10.04 Areas and lengths in polar coordinates`
# - [ ] `10 Parametric equations and polar coordinates::10.05 Conic sections`
# - [ ] `10 Parametric equations and polar coordinates::10.06 Conic sections in polar coordinates`
# - [ ] `12 Vectors and the geometry of space::12.01 Three-dimensional coordinate systems`
# - [ ] `12 Vectors and the geometry of space::12.02 Vectors`
# - [ ] `12 Vectors and the geometry of space::12.03 The dot product`
# - [ ] `12 Vectors and the geometry of space::12.04 The cross product`
# - [ ] `12 Vectors and the geometry of space::12.05 Equations of lines and planes`
# - [ ] `12 Vectors and the geometry of space::12.06 Cylinders and quadric surfaces`
# - [ ] `13 Vector functions::13.01 Vector functions and space curves`
# - [ ] `13 Vector functions::13.02 Derivatives and integrals of vector functions`
# - [ ] `13 Vector functions::13.03 Arc length and curvature`
# - [ ] `13 Vector functions::13.04 Motion in space: velocity and acceleration`
# - [ ] `14 Partial derivatives::14.01 Functions of several variables`
# - [ ] `14 Partial derivatives::14.02 Limits and continuity`
# - [ ] `14 Partial derivatives::14.03 Partial derivatives`
# - [ ] `14 Partial derivatives::14.04 Tangent planes and linear approximations`
# - [ ] `14 Partial derivatives::14.05 The Chain Rule`
# - [ ] `14 Partial derivatives::14.06 Directional derivatives and the gradient vector`
# - [ ] `14 Partial derivatives::14.07 Maximum and minimum values`
# - [ ] `14 Partial derivatives::14.08 Lagrange multipliers`
# - [ ] `15 Multiple integrals::15.01 Double integrals over rectangles`
# - [ ] `15 Multiple integrals::15.02 Double integrals over general regions`
# - [ ] `15 Multiple integrals::15.03 Double integrals in polar coordinates`
# - [ ] `15 Multiple integrals::15.04 Applications of double integrals`
# - [ ] `15 Multiple integrals::15.05 Surface area`
# - [ ] `15 Multiple integrals::15.06 Triple integrals`
# - [ ] `15 Multiple integrals::15.07 Triple integrals in cylindrical coordinates`
# - [ ] `15 Multiple integrals::15.08 Triple integrals in spherical coordinates`
# - [ ] `15 Multiple integrals::15.09 Change of variables in multiple integrals`
# - [ ] `16 Vector calculus::16.01 Vector fields`
# - [ ] `16 Vector calculus::16.02 Line integrals`
# - [ ] `16 Vector calculus::16.03 The Fundamental Theorem for Line integrals`
# - [ ] `16 Vector calculus::16.04 Green's Theorem`
# - [ ] `16 Vector calculus::16.05 Curl and divergence`
# - [ ] `16 Vector calculus::16.06 Parametric surfaces and their areas`
# - [ ] `16 Vector calculus::16.07 Surface integrals`
# - [ ] `16 Vector calculus::16.08 Stoke's Theorem`
# - [ ] `16 Vector calculus::16.09 The Divergence Theorem`

# %%
chapters = [
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::02 Limits and derivatives::02.02 The limit of a function',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::02 Limits and derivatives::02.03 Calculating limits using the limit laws',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::02 Limits and derivatives::02.04 The precise definition of a limit',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::02 Limits and derivatives::02.05 Continuity',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::02 Limits and derivatives::02.06 Limits at infinity; horizontal asymptotes',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.01 Derivatives of polynomials and exponential functions',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.02 The product and quotient rules',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.03 Derivatives of trigonometric functions',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.04 The Chain Rule',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.05 Implicit differentiation',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.06 Derivatives of logarithmic functions',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.07 Rates of change in the natural and social sciences',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.08 Exponential growth and decay',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.09 Related rates',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.10 Linear approximations and differentials',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.11 Hyperbolic functions',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::04 Applications of differentiation::04.01 Maximum and minimum values',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::04 Applications of differentiation::04.02 The Mean Value Theorem',
 "Math::Calculus::Stewart; Calculus: Early Trancendentals::04 Applications of differentiation::04.04 Indeterminate forms and L'Hospital's Rule",
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::04 Applications of differentiation::04.07 Optimization problems',
 "Math::Calculus::Stewart; Calculus: Early Trancendentals::04 Applications of differentiation::04.08 Newton's Method",
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::05 Integrals::05.03 The Fundamental Theorem of Calculus',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::05 Integrals::05.05 The Substitution Rule',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::06 Applications of integration::06.01 Areas between curves',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::06 Applications of integration::06.02 Volumes',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::06 Applications of integration::06.03 Volumes by cylindrical shells',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::06 Applications of integration::06.04 Work',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::06 Applications of integration::06.05 Average value of a function',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::07 Techniques of integration::07.01 Integration by parts',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::07 Techniques of integration::07.02 Trigonometric integrals',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::07 Techniques of integration::07.03 Trigonometric substitution',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::07 Techniques of integration::07.04 Integration of rational functions by partial fractions',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::07 Techniques of integration::07.05 Strategy for integration',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::07 Techniques of integration::07.07 Approximate integration',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::07 Techniques of integration::07.08 Improper integrals',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::08 Further applications of integration::08.01 Arc length',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::08 Further applications of integration::08.02 Area of a surface of revolution',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::08 Further applications of integration::08.03 Applications to physics and engineering',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::09 Differential equations::09.01 Modeling with differential equations',
 "Math::Calculus::Stewart; Calculus: Early Trancendentals::09 Differential equations::09.02 Direction fields and Euler's Method",
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::09 Differential equations::09.03 Separable equations',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::09 Differential equations::09.04 Models for population growth',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::09 Differential equations::09.05 Linear equations',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::09 Differential equations::09.06 Predator-prey systems',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::10 Parametric equations and polar coordinates::10.01 Curves defined by parametric equations',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::10 Parametric equations and polar coordinates::10.02 Calculus with parametric curves',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::10 Parametric equations and polar coordinates::10.03 Polar coordinates',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::10 Parametric equations and polar coordinates::10.04 Areas and lengths in polar coordinates',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::10 Parametric equations and polar coordinates::10.05 Conic sections',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::10 Parametric equations and polar coordinates::10.06 Conic sections in polar coordinates',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.01 Sequences',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.02 Series',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.03 The integral test and estimates of sums',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.04 The comparison tests',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.05 Alternating series',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.06 Absolute convergence and the Ratio and Root Tests',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.07 Strategy for testing series',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.08 Power series',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.09 Representations of functions as power series',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.10 Taylor and Maclaurin series',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.11 Applications of Taylor polynomials',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::12 Vectors and the geometry of space::12.01 Three-dimensional coordinate systems',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::12 Vectors and the geometry of space::12.02 Vectors',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::12 Vectors and the geometry of space::12.03 The dot product',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::12 Vectors and the geometry of space::12.04 The cross product',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::12 Vectors and the geometry of space::12.05 Equations of lines and planes',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::12 Vectors and the geometry of space::12.06 Cylinders and quadric surfaces',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::13 Vector functions::13.01 Vector functions and space curves',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::13 Vector functions::13.02 Derivatives and integrals of vector functions',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::13 Vector functions::13.03 Arc length and curvature',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::13 Vector functions::13.04 Motion in space: velocity and acceleration',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.01 Functions of several variables',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.02 Limits and continuity',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.03 Partial derivatives',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.04 Tangent planes and linear approximations',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.05 The Chain Rule',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.06 Directional derivatives and the gradient vector',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.07 Maximum and minimum values',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.08 Lagrange multipliers',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.01 Double integrals over rectangles',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.02 Double integrals over general regions',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.03 Double integrals in polar coordinates',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.04 Applications of double integrals',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.05 Surface area',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.06 Triple integrals',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.07 Triple integrals in cylindrical coordinates',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.08 Triple integrals in spherical coordinates',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.09 Change of variables in multiple integrals',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::16.01 Vector fields',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::16.02 Line integrals',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::16.03 The Fundamental Theorem for Line integrals',
 "Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::16.04 Green's Theorem",
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::16.05 Curl and divergence',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::16.06 Parametric surfaces and their areas',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::16.07 Surface integrals',
 "Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::16.08 Stoke's Theorem",
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::16.09 The Divergence Theorem',
]

# %%
chapters = ['::'.join(c.split('::')[-2:]) for c in chapters]
chapters
# Out:
# ['02 Limits and derivatives::02.02 The limit of a function',
#  '02 Limits and derivatives::02.03 Calculating limits using the limit laws',
#  '02 Limits and derivatives::02.04 The precise definition of a limit',
#  '02 Limits and derivatives::02.05 Continuity',
#  '02 Limits and derivatives::02.06 Limits at infinity; horizontal asymptotes',
#  '03 Differentiation rules::03.01 Derivatives of polynomials and exponential functions',
#  '03 Differentiation rules::03.02 The product and quotient rules',
#  '03 Differentiation rules::03.03 Derivatives of trigonometric functions',
#  '03 Differentiation rules::03.04 The Chain Rule',
#  '03 Differentiation rules::03.05 Implicit differentiation',
#  '03 Differentiation rules::03.06 Derivatives of logarithmic functions',
#  '03 Differentiation rules::03.07 Rates of change in the natural and social sciences',
#  '03 Differentiation rules::03.08 Exponential growth and decay',
#  '03 Differentiation rules::03.09 Related rates',
# ...

# %%
sections = chapters[:-36]

# %%
print('\n'.join(
  f'- [ ] `{s}`' for s in sections
))
# Out:
# - [ ] `02 Limits and derivatives::02.02 The limit of a function`
# - [ ] `02 Limits and derivatives::02.03 Calculating limits using the limit laws`
# - [ ] `02 Limits and derivatives::02.04 The precise definition of a limit`
# - [ ] `02 Limits and derivatives::02.05 Continuity`
# - [ ] `02 Limits and derivatives::02.06 Limits at infinity; horizontal asymptotes`
# - [ ] `03 Differentiation rules::03.01 Derivatives of polynomials and exponential functions`
# - [ ] `03 Differentiation rules::03.02 The product and quotient rules`
# - [ ] `03 Differentiation rules::03.03 Derivatives of trigonometric functions`
# - [ ] `03 Differentiation rules::03.04 The Chain Rule`
# - [ ] `03 Differentiation rules::03.05 Implicit differentiation`
# - [ ] `03 Differentiation rules::03.06 Derivatives of logarithmic functions`
# - [ ] `03 Differentiation rules::03.07 Rates of change in the natural and social sciences`
# - [ ] `03 Differentiation rules::03.08 Exponential growth and decay`
# ...

# %%
list(filter(lambda x: 'Stewart; Calculus: Early' in x and 'Examples' not in x and 'Exercises' not in x and 'Theory' not in x and 'Proofs' not in x, mw.col.decks.all_names()))
# Out:
# tmp/ipykernel_1360231/2025249306.py:1:all_names is deprecated: please use 'all_names_and_ids'
# ['Math::Calculus::#topics::CET::Stewart; Calculus: Early Trancendentals',
#  'Math::Calculus::#topics::CET::Stewart; Calculus: Early Trancendentals::Comprehensive cram (currently disabled)',
#  'Math::Calculus::Stewart; Calculus: Early Trancendentals',
#  'Math::Calculus::Stewart; Calculus: Early Trancendentals::00 Diagnostic tests',
#  'Math::Calculus::Stewart; Calculus: Early Trancendentals::00 Diagnostic tests::00-A Algebra',
#  'Math::Calculus::Stewart; Calculus: Early Trancendentals::00 Diagnostic tests::00-B Analytic geometry',
#  'Math::Calculus::Stewart; Calculus: Early Trancendentals::00 Diagnostic tests::00-C Functions',
#  'Math::Calculus::Stewart; Calculus: Early Trancendentals::00 Diagnostic tests::00-D Trigonometry',
#  'Math::Calculus::Stewart; Calculus: Early Trancendentals::01 Functions and models',
# ...

# %%
decks = [
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::02 Limits and derivatives::02.02 The limit of a function',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::02 Limits and derivatives::02.03 Calculating limits using the limit laws',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::02 Limits and derivatives::02.04 The precise definition of a limit',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::02 Limits and derivatives::02.05 Continuity',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::02 Limits and derivatives::02.06 Limits at infinity; horizontal asymptotes',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.01 Derivatives of polynomials and exponential functions',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.02 The product and quotient rules',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.03 Derivatives of trigonometric functions',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.04 The Chain Rule',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.05 Implicit differentiation',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.06 Derivatives of logarithmic functions',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.07 Rates of change in the natural and social sciences',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.08 Exponential growth and decay',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.09 Related rates',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.10 Linear approximations and differentials',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::03 Differentiation rules::03.11 Hyperbolic functions',
 "Math::Calculus::Stewart; Calculus: Early Trancendentals::04 Applications of differentiation::04.04 Indeterminate forms and L'Hospital's Rule",
 "Math::Calculus::Stewart; Calculus: Early Trancendentals::04 Applications of differentiation::04.08 Newton's Method",
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::05 Integrals',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::05 Integrals::05.05 The Substitution Rule',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::06 Applications of integration',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::06 Applications of integration::06.01 Areas between curves',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::06 Applications of integration::06.02 Volumes',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::06 Applications of integration::06.03 Volumes by cylindrical shells',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::06 Applications of integration::06.04 Work',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::06 Applications of integration::06.05 Average value of a function',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::07 Techniques of integration',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::07 Techniques of integration::07.01 Integration by parts',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::07 Techniques of integration::07.01 Integration by parts::Original typeset exercises',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::07 Techniques of integration::07.02 Trigonometric integrals',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::07 Techniques of integration::07.03 Trigonometric substitution',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::07 Techniques of integration::07.04 Integration of rational functions by partial fractions',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::07 Techniques of integration::07.05 Strategy for integration',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::07 Techniques of integration::07.07 Approximate integration',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::07 Techniques of integration::07.08 Improper integrals',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::08 Further applications of integration',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::08 Further applications of integration::08.01 Arc length',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::08 Further applications of integration::08.02 Area of a surface of revolution',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::08 Further applications of integration::08.03 Applications to physics and engineering',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::09 Differential equations',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::09 Differential equations::09.01 Modeling with differential equations',
 "Math::Calculus::Stewart; Calculus: Early Trancendentals::09 Differential equations::09.02 Direction fields and Euler's Method",
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::09 Differential equations::09.03 Separable equations',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::09 Differential equations::09.04 Models for population growth',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::09 Differential equations::09.05 Linear equations',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::09 Differential equations::09.06 Predator-prey systems',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::10 Parametric equations and polar coordinates',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::10 Parametric equations and polar coordinates::10.01 Curves defined by parametric equations',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::10 Parametric equations and polar coordinates::10.02 Calculus with parametric curves',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::10 Parametric equations and polar coordinates::10.03 Polar coordinates',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::10 Parametric equations and polar coordinates::10.04 Areas and lengths in polar coordinates',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::10 Parametric equations and polar coordinates::10.05 Conic sections',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::10 Parametric equations and polar coordinates::10.06 Conic sections in polar coordinates',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.01 Sequences',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.02 Series',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.03 The integral test and estimates of sums',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.04 The comparison tests',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.05 Alternating series',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.06 Absolute convergence and the Ratio and Root Tests',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.07 Strategy for testing series',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.08 Power series',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.09 Representations of functions as power series',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.10 Taylor and Maclaurin series',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::11 Infinite sequences and series::11.11 Applications of Taylor polynomials',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::12 Vectors and the geometry of space',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::12 Vectors and the geometry of space::12.01 Three-dimensional coordinate systems',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::12 Vectors and the geometry of space::12.02 Vectors',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::12 Vectors and the geometry of space::12.03 The dot product',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::12 Vectors and the geometry of space::12.04 The cross product',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::12 Vectors and the geometry of space::12.05 Equations of lines and planes',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::12 Vectors and the geometry of space::12.06 Cylinders and quadric surfaces',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::12 Vectors and the geometry of space::Problems Plus',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::12 Vectors and the geometry of space::Review',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::12 Vectors and the geometry of space::Review::True-False',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::12 Vectors and the geometry of space::Review::True-False cram',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::13 Vector functions',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::13 Vector functions::13.01 Vector functions and space curves',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::13 Vector functions::13.02 Derivatives and integrals of vector functions',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::13 Vector functions::13.03 Arc length and curvature',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::13 Vector functions::13.04 Motion in space: velocity and acceleration',
 "Math::Calculus::Stewart; Calculus: Early Trancendentals::13 Vector functions::Applied Project: Kepler's Laws",
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::13 Vector functions::Problems Plus',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::13 Vector functions::Review',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::13 Vector functions::Review::True-False',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::13 Vector functions::Review::True-False cram',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.01 Functions of several variables',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.02 Limits and continuity',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.03 Partial derivatives',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.04 Tangent planes and linear approximations',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.04 Tangent planes and linear approximations::Applied project, the Speedo LZR racer',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.04 Tangent planes and linear approximations::Applied project, the Speedo LZR racer, cram',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.05 The Chain Rule',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.06 Directional derivatives and the gradient vector',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.07 Maximum and minimum values',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.07 Maximum and minimum values::Applied project, designing a dumpster',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.07 Maximum and minimum values::Applied project, designing a dumpster, cram',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.07 Maximum and minimum values::Discovery project, quadratic approximations and critical points',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.07 Maximum and minimum values::Discovery project, quadratic approximations and critical points, cram',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.08 Lagrange multipliers',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.08 Lagrange multipliers::Applied project, hydro-turbine optimization',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.08 Lagrange multipliers::Applied project, hydro-turbine optimization, cram',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.08 Lagrange multipliers::Applied project, rocket science',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::14.08 Lagrange multipliers::Applied project, rocket science, cram',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::Review',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::Review::True-False',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::14 Partial derivatives::Review::True-False cram',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.01 Double integrals over rectangles',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.02 Double integrals over general regions',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.03 Double integrals in polar coordinates',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.04 Applications of double integrals',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.05 Surface area',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.06 Triple integrals',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.06 Triple integrals::Discovery project, volumes of hyperspheres',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.06 Triple integrals::Discovery project, volumes of hyperspheres, cram',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.07 Triple integrals in cylindrical coordinates',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.07 Triple integrals in cylindrical coordinates::Discovery project, the intersection of three cylinders',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.07 Triple integrals in cylindrical coordinates::Discovery project, the intersection of three cylinders, cram',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.08 Triple integrals in spherical coordinates',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.08 Triple integrals in spherical coordinates::Applied project, roller derby',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.08 Triple integrals in spherical coordinates::Applied project, roller derby, cram',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::15.09 Change of variables in multiple integrals',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::Problems Plus',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::Review',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::Review::True-False',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::15 Multiple integrals::Review::True-False cram',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::16.01 Vector fields',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::16.02 Line integrals',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::16.03 The Fundamental Theorem for Line integrals',
 "Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::16.04 Green's Theorem",
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::16.05 Curl and divergence',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::16.06 Parametric surfaces and their areas',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::16.07 Surface integrals',
 "Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::16.08 Stoke's Theorem",
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::16.09 The Divergence Theorem',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::Problems Plus',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::Review',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::Review::True-False',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::16 Vector calculus::Review::True-False cram',
 'Math::Calculus::Stewart; Calculus: Early Trancendentals::Comprehensive cram (currently disabled)']
